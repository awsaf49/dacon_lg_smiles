# %%
from rdkit.Chem import AllChem
from rdkit.Chem import Draw

from rdkit import Chem
from rdkit import DataStructs
from rdkit import RDLogger
RDLogger.DisableLog('rdApp.*')

# %%
#template = Chem.MolFromSmiles('O=Cc1ccc(O)c(OC)c1')
#Draw.MolToMPL(template, size=(200,200))

m = Chem.MolFromSmiles('O=C(O)C1(N)CCCC1')
Draw.MolToMPL(m, size=(200,200))      
m2 = Chem.MolFromSmiles('NC1(CCCC1)C(O)=O')
Draw.MolToMPL(m2, size=(200,200))
m3 = Chem.MolFromSmiles('OC(=O)C1(N)CCCC1')
Draw.MolToMPL(m3, size=(200,200))
m4 = Chem.MolFromSmiles('C1CCCC1(N)C(O)=O')
Draw.MolToMPL(m4, size=(200,200))
